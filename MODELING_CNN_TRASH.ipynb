# %%
import tensorflow as tf
data = tf.keras.utils.image_dataset_from_directory('/Users/ADVAN/Downloads/projekpython14juni/Dataset Sampah')
# Out:
# Found 250 files belonging to 5 classes.

# %%
# Get the class names
class_names = data.class_names

# Print the class names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic']

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
batch[0].shape
# Out:
# (32, 256, 256, 3)

# %%
batch[1].shape
# Out:
# (32,)

# %% [markdown]
# # MELIHAT SAMPEL IMAGE

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=2, ncols=6, figsize=(20,20))
for idx, img in enumerate(batch[0][:12]):
    row_idx = idx // 6  # Determine the row index
    col_idx = idx % 6   # Determine the column index
    ax[row_idx, col_idx].imshow(img.astype(int))
    ax[row_idx, col_idx].title.set_text(str(batch[1][idx]))

plt.tight_layout(rect=[0, 0, 1, 0.70])  # Adjust the layout and specify the rectangle
plt.show()

# %% [markdown]
# # SCALED PIXEL VALUE 0-255 TO 0-1

# %%
# Applying the scaling operation
data = data.map(lambda x, y: (x/255, y))

# %%
data.as_numpy_iterator().next()
# Out:
# (array([[[[0.94803923, 0.8539216 , 0.7441176 ],
#           [0.94803923, 0.8539216 , 0.7441176 ],
#           [0.94803923, 0.8539216 , 0.7441176 ],
#           ...,
#           [0.70392156, 0.58235294, 0.46078432],
#           [0.6960784 , 0.5745098 , 0.45294118],
#           [0.6906863 , 0.56911767, 0.44754902]],
#
#          [[0.94509804, 0.8509804 , 0.7411765 ],
#           [0.94509804, 0.8509804 , 0.7411765 ],
#           [0.94509804, 0.8509804 , 0.7411765 ],
#           ...,
#           [0.70392156, 0.58235294, 0.46078432],
#           [0.6960784 , 0.5745098 , 0.45294118],
#           [0.6936275 , 0.5720588 , 0.4504902 ]],
#
#          [[0.94411767, 0.85      , 0.74019605],
#           [0.94411767, 0.85      , 0.74019605],
#           [0.94411767, 0.85      , 0.74019605],
#           ...,
#           [0.7019608 , 0.5803922 , 0.45882353],
#           [0.69803923, 0.5764706 , 0.45490196],
#           [0.69509804, 0.5735294 , 0.45196077]],
#
#          ...,
#
#          [[0.59117645, 0.5088235 , 0.40294117],
#           [0.59117645, 0.5088235 , 0.40294117],
#           [0.59117645, 0.5088235 , 0.40294117],
#           ...,
#           [0.44215685, 0.37156862, 0.27745098],
#           [0.44019607, 0.36960784, 0.2754902 ],
#           [0.44019607, 0.36960784, 0.2754902 ]],
#
#          [[0.5921569 , 0.50980395, 0.40392157],
#           [0.5921569 , 0.50980395, 0.40392157],
#           [0.5921569 , 0.50980395, 0.40392157],
#           ...,
#           [0.44313726, 0.37254903, 0.2784314 ],
#           [0.4392157 , 0.36862746, 0.27450982],
#           [0.43823528, 0.36764705, 0.2735294 ]],
#
#          [[0.595098  , 0.5127451 , 0.40686274],
#           [0.595098  , 0.5127451 , 0.40686274],
#           [0.595098  , 0.5127451 , 0.40686274],
#           ...,
#           [0.44313726, 0.37254903, 0.2784314 ],
#           [0.4392157 , 0.36862746, 0.27450982],
#           [0.43529412, 0.3647059 , 0.27058825]]],
#
#
#         [[[0.89411765, 0.84705883, 0.7921569 ],
#           [0.89411765, 0.84705883, 0.7921569 ],
#           [0.89411765, 0.84705883, 0.7921569 ],
#           ...,
#           [0.81960785, 0.7764706 , 0.7058824 ],
#           [0.8156863 , 0.77254903, 0.7019608 ],
#           [0.8151961 , 0.77205884, 0.7014706 ]],
#
#          [[0.89411765, 0.84705883, 0.7921569 ],
#           [0.89411765, 0.84705883, 0.7921569 ],
#           [0.89411765, 0.84705883, 0.7921569 ],
#           ...,
#           [0.8181372 , 0.775     , 0.70441175],
#           [0.8156863 , 0.77254903, 0.7019608 ],
#           [0.8122549 , 0.76911765, 0.6985294 ]],
#
#          [[0.89411765, 0.84705883, 0.7921569 ],
#           [0.89411765, 0.84705883, 0.7921569 ],
#           [0.89411765, 0.84705883, 0.7921569 ],
#           ...,
#           [0.8156863 , 0.77254903, 0.7019608 ],
#           [0.8132353 , 0.77009803, 0.6995098 ],
#           [0.81078434, 0.7676471 , 0.6970588 ]],
#
#          ...,
#
#          [[0.8901961 , 0.85882354, 0.8156863 ],
#           [0.8901961 , 0.85882354, 0.8156863 ],
#           [0.8901961 , 0.85882354, 0.8156863 ],
#           ...,
#           [0.88529414, 0.8421569 , 0.7558824 ],
#           [0.88529414, 0.8421569 , 0.7558824 ],
#           [0.88529414, 0.8421569 , 0.7558824 ]],
#
#          [[0.8901961 , 0.85882354, 0.8156863 ],
#           [0.8901961 , 0.85882354, 0.8156863 ],
#           [0.8901961 , 0.85882354, 0.8156863 ],
#           ...,
#           [0.8862745 , 0.84313726, 0.75686276],
#           [0.8862745 , 0.84313726, 0.75686276],
#           [0.8862745 , 0.84313726, 0.75686276]],
#
#          [[0.8901961 , 0.85882354, 0.8156863 ],
#           [0.8901961 , 0.85882354, 0.8156863 ],
#           [0.8901961 , 0.85882354, 0.8156863 ],
#           ...,
#           [0.8892157 , 0.84607846, 0.75980395],
#           [0.8892157 , 0.84607846, 0.75980395],
#           [0.8892157 , 0.84607846, 0.75980395]]],
#
#
#         [[[0.8       , 0.78431374, 0.7490196 ],
#           [0.79607844, 0.78039217, 0.74509805],
#           [0.79607844, 0.78039217, 0.74509805],
#           ...,
#           [0.8117647 , 0.7882353 , 0.7254902 ],
#           [0.8117647 , 0.7882353 , 0.7254902 ],
#           [0.8117647 , 0.7882353 , 0.7254902 ]],
#
#          [[0.8014706 , 0.7857843 , 0.7504902 ],
#           [0.797549  , 0.78186274, 0.7465686 ],
#           [0.797549  , 0.78186274, 0.7465686 ],
#           ...,
#           [0.8117647 , 0.7882353 , 0.7254902 ],
#           [0.8117647 , 0.7882353 , 0.7254902 ],
#           [0.8117647 , 0.7882353 , 0.7254902 ]],
#
#          [[0.80441177, 0.7887255 , 0.7534314 ],
#           [0.8       , 0.78431374, 0.7490196 ],
#           [0.8       , 0.78431374, 0.7490196 ],
#           ...,
#           [0.8117647 , 0.7882353 , 0.7254902 ],
#           [0.8117647 , 0.7882353 , 0.7254902 ],
#           [0.8117647 , 0.7882353 , 0.7254902 ]],
#
#          ...,
#
#          [[0.89411765, 0.8784314 , 0.8352941 ],
#           [0.89411765, 0.8784314 , 0.8352941 ],
#           [0.89411765, 0.8784314 , 0.8352941 ],
#           ...,
#           [0.89411765, 0.87058824, 0.78431374],
#           [0.89411765, 0.87058824, 0.78431374],
#           [0.89411765, 0.87058824, 0.78431374]],
#
#          [[0.89411765, 0.8784314 , 0.8352941 ],
#           [0.89411765, 0.8784314 , 0.8352941 ],
#           [0.89411765, 0.8784314 , 0.8352941 ],
#           ...,
#           [0.89411765, 0.87058824, 0.78431374],
#           [0.89411765, 0.87058824, 0.78431374],
#           [0.89411765, 0.87058824, 0.78431374]],
#
#          [[0.89411765, 0.8784314 , 0.8352941 ],
#           [0.89411765, 0.8784314 , 0.8352941 ],
#           [0.89411765, 0.8784314 , 0.8352941 ],
#           ...,
#           [0.89411765, 0.87058824, 0.78431374],
#           [0.89411765, 0.87058824, 0.78431374],
#           [0.89411765, 0.87058824, 0.78431374]]],
#
#
#         ...,
#
#
#         [[[0.9637255 , 0.99509805, 1.        ],
#           [0.9637255 , 0.99509805, 1.        ],
#           [0.9637255 , 0.99509805, 1.        ],
#           ...,
#           [0.76862746, 0.77254903, 0.7490196 ],
#           [0.7647059 , 0.76862746, 0.74509805],
#           [0.7632353 , 0.76715684, 0.7436274 ]],
#
#          [[0.9607843 , 0.99215686, 1.        ],
#           [0.9607843 , 0.99215686, 1.        ],
#           [0.9607843 , 0.99215686, 1.        ],
#           ...,
#           [0.77009803, 0.7740196 , 0.7504902 ],
#           [0.76617646, 0.77009803, 0.7465686 ],
#           [0.7647059 , 0.76862746, 0.74509805]],
#
#          [[0.95980394, 0.9911765 , 0.9990196 ],
#           [0.95980394, 0.9911765 , 0.9990196 ],
#           [0.95980394, 0.9911765 , 0.9990196 ],
#           ...,
#           [0.77254903, 0.7764706 , 0.7529412 ],
#           [0.76911765, 0.7730392 , 0.7495098 ],
#           [0.7656863 , 0.76960784, 0.74607843]],
#
#          ...,
#
#          [[0.92941177, 0.93333334, 0.9137255 ],
#           [0.9313725 , 0.9352941 , 0.91568625],
#           [0.92745095, 0.9313725 , 0.9117647 ],
#           ...,
#           [0.6637255 , 0.66764706, 0.64411765],
#           [0.6637255 , 0.66764706, 0.64411765],
#           [0.6637255 , 0.66764706, 0.64411765]],
#
#          [[0.92941177, 0.93333334, 0.9137255 ],
#           [0.9313725 , 0.9352941 , 0.91568625],
#           [0.92745095, 0.9313725 , 0.9117647 ],
#           ...,
#           [0.6627451 , 0.6666667 , 0.6431373 ],
#           [0.6627451 , 0.6666667 , 0.6431373 ],
#           [0.6627451 , 0.6666667 , 0.6431373 ]],
#
#          [[0.92941177, 0.93333334, 0.9137255 ],
#           [0.9313725 , 0.9352941 , 0.91568625],
#           [0.92745095, 0.9313725 , 0.9117647 ],
#           ...,
#           [0.6598039 , 0.6637255 , 0.6401961 ],
#           [0.6598039 , 0.6637255 , 0.6401961 ],
#           [0.6598039 , 0.6637255 , 0.6401961 ]]],
#
#
#         [[[0.79607844, 0.7137255 , 0.6313726 ],
#           [0.79607844, 0.7137255 , 0.6313726 ],
#           [0.79607844, 0.7137255 , 0.6313726 ],
#           ...,
#           [0.5833333 , 0.51666665, 0.45392156],
#           [0.5833333 , 0.51666665, 0.45392156],
#           [0.5833333 , 0.51666665, 0.45392156]],
#
#          [[0.79607844, 0.7137255 , 0.6313726 ],
#           [0.79607844, 0.7137255 , 0.6313726 ],
#           [0.79607844, 0.7137255 , 0.6313726 ],
#           ...,
#           [0.5803922 , 0.5137255 , 0.4509804 ],
#           [0.5803922 , 0.5137255 , 0.4509804 ],
#           [0.5803922 , 0.5137255 , 0.4509804 ]],
#
#          [[0.79607844, 0.7137255 , 0.6313726 ],
#           [0.79607844, 0.7137255 , 0.6313726 ],
#           [0.79607844, 0.7137255 , 0.6313726 ],
#           ...,
#           [0.57941175, 0.5127451 , 0.45      ],
#           [0.57941175, 0.5127451 , 0.45      ],
#           [0.57941175, 0.5127451 , 0.45      ]],
#
#          ...,
#
#          [[0.75686276, 0.6745098 , 0.5921569 ],
#           [0.75686276, 0.6745098 , 0.5921569 ],
#           [0.75686276, 0.6745098 , 0.5921569 ],
#           ...,
#           [0.42745098, 0.36862746, 0.29411766],
#           [0.42745098, 0.36862746, 0.29411766],
#           [0.42745098, 0.36862746, 0.29411766]],
#
#          [[0.75686276, 0.6745098 , 0.5921569 ],
#           [0.75686276, 0.6745098 , 0.5921569 ],
#           [0.75686276, 0.6745098 , 0.5921569 ],
#           ...,
#           [0.42745098, 0.36862746, 0.29411766],
#           [0.42745098, 0.36862746, 0.29411766],
#           [0.42745098, 0.36862746, 0.29411766]],
#
#          [[0.75686276, 0.6745098 , 0.5921569 ],
#           [0.75686276, 0.6745098 , 0.5921569 ],
#           [0.75686276, 0.6745098 , 0.5921569 ],
#           ...,
#           [0.42745098, 0.36862746, 0.29411766],
#           [0.42745098, 0.36862746, 0.29411766],
#           [0.42745098, 0.36862746, 0.29411766]]],
#
#
#         [[[0.17892157, 0.16323529, 0.15147059],
#           [0.15686275, 0.14117648, 0.12941177],
#           [0.13382353, 0.11813726, 0.10637255],
#           ...,
#           [0.10784314, 0.3882353 , 0.6166667 ],
#           [0.1122549 , 0.35392156, 0.62352943],
#           [0.13137256, 0.3240196 , 0.6367647 ]],
#
#          [[0.17450981, 0.15882353, 0.14705883],
#           [0.15833333, 0.14264706, 0.13088235],
#           [0.15      , 0.13431373, 0.12254902],
#           ...,
#           [0.13137256, 0.38235295, 0.6019608 ],
#           [0.14607844, 0.35833332, 0.6132353 ],
#           [0.1637255 , 0.3372549 , 0.62941176]],
#
#          [[0.18872549, 0.17303921, 0.16127451],
#           [0.16862746, 0.15294118, 0.14117648],
#           [0.16176471, 0.14607844, 0.13431373],
#           ...,
#           [0.15147059, 0.3612745 , 0.58186275],
#           [0.17009804, 0.35049018, 0.597549  ],
#           [0.19166666, 0.3367647 , 0.6137255 ]],
#
#          ...,
#
#          [[0.9906863 , 0.99264705, 0.93333334],
#           [0.9823529 , 0.9862745 , 0.9235294 ],
#           [0.99460787, 0.9965686 , 0.9495098 ],
#           ...,
#           [0.9745098 , 0.95098037, 0.8568627 ],
#           [0.96617645, 0.94264704, 0.8485294 ],
#           [0.9754902 , 0.9519608 , 0.85784316]],
#
#          [[0.9867647 , 0.9872549 , 0.93088233],
#           [0.98970586, 0.9916667 , 0.9348039 ],
#           [0.9872549 , 0.98970586, 0.93578434],
#           ...,
#           [0.95637256, 0.93284315, 0.8387255 ],
#           [0.9705882 , 0.9470588 , 0.85294116],
#           [0.9651961 , 0.94166666, 0.847549  ]],
#
#          [[0.99264705, 0.9887255 , 0.9397059 ],
#           [0.99264705, 0.99460787, 0.9436275 ],
#           [0.9872549 , 0.9911765 , 0.9284314 ],
#           ...,
#           [0.6843137 , 0.6607843 , 0.56666666],
#           [0.9602941 , 0.94411767, 0.85      ],
#           [0.9622549 , 0.9387255 , 0.84460783]]]], dtype=float32),
#  array([4, 1, 2, 1, 4, 2, 2, 1, 4, 4, 4, 1, 1, 2, 3, 3, 1, 2, 3, 1, 4, 0,
#         2, 3, 0, 2, 3, 2, 1, 3, 4, 3]))

# %% [markdown]
# # SPLIT DATA TO TRAIN AND VALIDATION

# %%
len(data)
# Out:
# 8

# %%
train_size = int(len(data)*.9)
val_size = int(len(data)*.1)+1

# %% [markdown]
# TRAIN SIZE 90%

# %%
train_size
# Out:
# 7

# %% [markdown]
# VAL SIZE 10%

# %%
val_size
# Out:
# 1

# %%
train_size+val_size
# Out:
# 8

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)

# %% [markdown]
# # MODELLING WITH CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(6, activation='softmax'))
# Out:
# C:\Users\ADVAN\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam',
                loss = 'sparse_categorical_crossentropy',
                metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 14400)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     3,686,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │         1,542 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,697,910 (14.11 MB)
#  Trainable params: 3,697,910 (14.11 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # CUSTOM CALLBACKS IF REACH ACCURACY 98

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback

class AccuracyStopCallback(Callback):
    def __init__(self, target_accuracy=0.98):
        super(AccuracyStopCallback, self).__init__()
        self.target_accuracy = target_accuracy

    def on_epoch_end(self, epoch, logs=None):
        if logs['accuracy'] >= self.target_accuracy:
            self.model.stop_training = True

# Create an instance of the AccuracyStopCallback
accuracy_stop_callback = AccuracyStopCallback(target_accuracy=0.98)

# %% [markdown]
# # TRAINING

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[accuracy_stop_callback])
# Out:
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 349ms/step - accuracy: 0.1991 - loss: 2.0699 - val_accuracy: 0.2308 - val_loss: 1.6113
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - accuracy: 0.2431 - loss: 1.6536 - val_accuracy: 0.3077 - val_loss: 1.5766
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 293ms/step - accuracy: 0.3522 - loss: 1.5569 - val_accuracy: 0.2692 - val_loss: 1.5258
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - accuracy: 0.3959 - loss: 1.4142 - val_accuracy: 0.6154 - val_loss: 1.2089
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step - accuracy: 0.5338 - loss: 1.2671 - val_accuracy: 0.8077 - val_loss: 0.9350
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step - accuracy: 0.5989 - loss: 1.0766 - val_accuracy: 0.3077 - val_loss: 1.3057
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - accuracy: 0.6267 - loss: 1.0491 - val_accuracy: 0.7692 - val_loss: 0.6683
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - accuracy: 0.6056 - loss: 0.9368 - val_accuracy: 0.7308 - val_loss: 0.7405
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 293ms/step - accuracy: 0.6933 - loss: 0.7315 - val_accuracy: 0.8462 - val_loss: 0.5100
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - accuracy: 0.6874 - loss: 0.7706 - val_accuracy: 0.8077 - val_loss: 0.5993
# Epoch 11/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step - accuracy: 0.7742 - loss: 0.6984 - val_accuracy: 0.8462 - val_loss: 0.6212
# Epoch 12/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 284ms/step - accuracy: 0.8465 - loss: 0.5036 - val_accuracy: 0.7692 - val_loss: 0.6094
# Epoch 13/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step - accuracy: 0.8585 - loss: 0.4128 - val_accuracy: 0.8462 - val_loss: 0.4252
# Epoch 14/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - accuracy: 0.8874 - loss: 0.3553 - val_accuracy: 0.8846 - val_loss: 0.3115
# Epoch 15/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step - accuracy: 0.9113 - loss: 0.3154 - val_accuracy: 0.9615 - val_loss: 0.2512
# Epoch 16/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step - accuracy: 0.9425 - loss: 0.2541 - val_accuracy: 1.0000 - val_loss: 0.0483
# Epoch 17/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 293ms/step - accuracy: 0.9544 - loss: 0.1954 - val_accuracy: 0.9231 - val_loss: 0.2831
# Epoch 18/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 293ms/step - accuracy: 0.9687 - loss: 0.1323 - val_accuracy: 1.0000 - val_loss: 0.0714
# Epoch 19/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 292ms/step - accuracy: 0.9628 - loss: 0.1409 - val_accuracy: 1.0000 - val_loss: 0.1682
# Epoch 20/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 330ms/step - accuracy: 0.9747 - loss: 0.1436 - val_accuracy: 1.0000 - val_loss: 0.1179

# %% [markdown]
# # PLOT ACCURACY AND LOSS

# %%
import matplotlib.pyplot as plt

acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig('accuracy_plot.png')  # Save the plot as an image
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig('loss_plot.png')  # Save the plot as an image

plt.show()

# %% [markdown]
# # TEST THE MODEL WITH AN INPUT IMAGE

# %%
import cv2
import matplotlib

# %% [markdown]
# preview the image first

# %%
img = cv2.imread('/Users/ADVAN/Downloads/projekpython14juni/trash/trash_034.jpg')
plt.imshow(img)
plt.show()

# %% [markdown]
# resize the image, karena model dilatih dengan input layer 256x256. maka gambar yang akan di test atau masukan ke model harus di resize juga menjadi 256x256

# %%
import numpy as np
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
import numpy as np

# Assuming `resize` is the image you want to predict
# Assuming `class_names` is the list of class names

# Preprocess the image
scaled_pixel_value = resize / 255.0
input_image = np.expand_dims(scaled_pixel_value, axis=0)

# Make predictions
yhat = model.predict(input_image)

# Get the predicted class index
predicted_class_index = np.argmax(yhat, axis=1)

# Get the predicted class name
predicted_class_name = class_names[predicted_class_index[0]]

# Get the class probabilities
class_probabilities = yhat[0]

# Print the predicted class and probabilities
print("Predicted class:", predicted_class_name)
print("Class probabilities:", class_probabilities)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Predicted class: paper
# Class probabilities: [2.2566039e-10 7.0979918e-04 7.9131864e-02 8.7422115e-01 4.5937233e-02
#  7.5775812e-20]
